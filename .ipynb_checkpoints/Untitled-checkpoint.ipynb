# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
df = pd.read_csv("data/results/output.txt", header=None, names=["mfccs", "window", "dist", "fn", "speaker", "guess"])
df["correct guess"] = df.apply(lambda x: x["speaker"] == x["guess"], axis=1)
fd = df.groupby(["mfccs", "window", "dist", "fn"]).size().reset_index().rename(columns={0:'count'})
fd["count"] = fd.apply(lambda x: np.mean(df[(df["mfccs"] == x["mfccs"])
                                            & (df["window"] == x["window"])
                                            & (df["dist"] == x["dist"])
                                            & (df["fn"] == x["fn"])]["correct guess"]), axis=1)

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
ax.scatter(x=fd["mfccs"].unique(),
           y=fd.apply(lambda x: np.mean(fd[fd["mfccs"] == x["mfccs"]]["count"]), axis=1).unique())
ax.set_xlabel('Number of static MFCCs')
ax.set_ylabel('Success rate (%)')

# %%
fd.corr()
# Out:
#                mfccs        window      dist     count
# mfccs   1.000000e+00  1.187684e-17  0.164454  0.432008
# window  1.187684e-17  1.000000e+00 -0.150125  0.056977
# dist    1.644539e-01 -1.501252e-01  1.000000 -0.470841
# count   4.320084e-01  5.697666e-02 -0.470841  1.000000

# %%
np.sum(df[df['mfccs'] == 12]["correct guess"])
# Out:
# 3738

# %%
fd.apply(lambda x: np.mean(fd[fd["mfccs"] == x["mfccs"]]["count"]), axis=1).unique()
# Out:
# array([0.91617647, 0.94681373, 0.97205882, 0.96544118])

# %%
fd
# Out:
#     mfccs  window   dist        fn     count
# 0      12   0.020  0.005  Blackman  0.988235
# 1      12   0.020  0.005   Hamming  0.982353
# 2      12   0.020  0.010  Blackman  0.929412
# 3      12   0.020  0.010   Hamming  0.935294
# 4      12   0.020  0.015  Blackman  0.900000
# 5      12   0.020  0.015   Hamming  0.900000
# 6      12   0.020  0.020  Blackman  0.823529
# 7      12   0.020  0.020   Hamming  0.823529
# 8      12   0.025  0.005  Blackman  0.976471
# 9      12   0.025  0.005   Hamming  0.982353
# 10     12   0.025  0.010  Blackman  0.952941
# 11     12   0.025  0.010   Hamming  0.952941
# 12     12   0.025  0.015  Blackman  0.911765
# 13     12   0.025  0.015   Hamming  0.911765
# 14     12   0.025  0.020  Blackman  0.847059
# 15     12   0.025  0.020   Hamming  0.847059
# 16     12   0.030  0.005  Blackman  0.964706
# 17     12   0.030  0.005   Hamming  0.964706
# 18     12   0.030  0.010  Blackman  0.952941
# 19     12   0.030  0.010   Hamming  0.952941
# ...

# %%
df
# Out:
#        mfccs  window   dist        fn          speaker            guess  \
# 0         12    0.02  0.005   Hamming  anthonyschaller  anthonyschaller
# 1         12    0.02  0.005   Hamming  anthonyschaller  anthonyschaller
# 2         12    0.02  0.005   Hamming  anthonyschaller  anthonyschaller
# 3         12    0.02  0.005   Hamming  anthonyschaller  anthonyschaller
# 4         12    0.02  0.005   Hamming  anthonyschaller  anthonyschaller
# 5         12    0.02  0.005   Hamming      Apple_Eater      Apple_Eater
# 6         12    0.02  0.005   Hamming      Apple_Eater      Apple_Eater
# 7         12    0.02  0.005   Hamming      Apple_Eater      Apple_Eater
# 8         12    0.02  0.005   Hamming      Apple_Eater      Apple_Eater
# 9         12    0.02  0.005   Hamming      Apple_Eater      Apple_Eater
# 10        12    0.02  0.005   Hamming              Ara              Ara
# 11        12    0.02  0.005   Hamming              Ara              Ara
# ...

# %%
np.mean(df[(df["mfccs"] == 12) & (df["fn"] == "Blackman")]["correct guess"])
# Out:
# 0.9156862745098039

# %%
data12 = []
with open("data/results/output12.txt") as f:
    data12 = f.read().split("\n\n")
data12
# Out:
# ['MFCCs: 12 / window: 0.02 / distance: 0.005\nanthonyschaller detected as - anthonyschaller\nanthonyschaller detected as - anthonyschaller\nanthonyschaller detected as - anthonyschaller\nanthonyschaller detected as - anthonyschaller\nanthonyschaller detected as - anthonyschaller\nApple_Eater detected as - Apple_Eater\nApple_Eater detected as - Apple_Eater\nApple_Eater detected as - Apple_Eater\nApple_Eater detected as - Apple_Eater\nApple_Eater detected as - Apple_Eater\nAra detected as - Ara\nAra detected as - Ara\nAra detected as - Ara\nAra detected as - Ara\nAra detected as - Ara\nargail detected as - argail\nargail detected as - argail\nargail detected as - argail\nargail detected as - argail\nargail detected as - argail\nariyan detected as - ariyan\nariyan detected as - ariyan\nariyan detected as - ariyan\nariyan detected as - ariyan\nariyan detected as - ariyan\narjuan detected as - arjuan\narjuan detected as - arjuan\narjuan detected as - arjuan\narjuan detected as - arjuan\na
# ...

# %%
data16 = []
with open("data/results/output16.txt") as f:
    data16 = f.read().split("\n\n")
data16 = [i.split("\n") for i in data16]
data16 = [j.split(" detected as - ") for i in data16 for j in i]

for i in data16:
    for j in i:
        if "MFCC" in j:
            values = j.split(" / ")
            data_df["mfccs"] += [int(values[0].split(" ")[1])] * 340
            data_df["ts"] += [float(values[1].split(" ")[1])] * 340
            data_df["dist"] += [float(values[2].split(" ")[1])] * 340
        elif len(j) == 2:
            data_df["speaker"].append(i[0])
            data_df["guess"].append(i[1])
        else:
            continue
            
data_df
# Out:
# {'mfccs': [12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
# ...

# %%
data20 = []
with open("data/results/output20.txt") as f:
    data20 = f.read().split("\n\n")
data20 = [i.split("\n") for i in data20]
data20 = [j.split(" detected as - ") for i in data20 for j in i]

for i in data20:
    for j in i:
        if "MFCC" in j:
            values = j.split(" / ")
            data_df["mfccs"] += [int(values[0].split(" ")[1])] * 340
            data_df["ts"] += [float(values[1].split(" ")[1])] * 340
            data_df["dist"] += [float(values[2].split(" ")[1])] * 340
        elif len(j) == 2:
            data_df["speaker"].append(i[0])
            data_df["guess"].append(i[1])
        else:
            continue
            
data_df
# Out:
# {'mfccs': [12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
# ...

# %%
data24 = []
with open("data/results/output24.txt") as f:
    data24 = f.read().split("\n\n")
data24 = [i.split("\n") for i in data24]
data24 = [j.split(" detected as - ") for i in data24 for j in i]

for i in data24:
    for j in i:
        if "MFCC" in j:
            values = j.split(" / ")
            data_df["mfccs"] += [int(values[0].split(" ")[1])] * 340
            data_df["ts"] += [float(values[1].split(" ")[1])] * 340
            data_df["dist"] += [float(values[2].split(" ")[1])] * 340
        elif len(j) == 2:
            data_df["speaker"].append(i[0])
            data_df["guess"].append(i[1])
        else:
            continue
            
data_df
# Out:
# {'mfccs': [12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
# ...

# %%
print(len(data_df["mfccs"]), len(data_df["ts"]), len(data_df["dist"]), len(data_df["speaker"]), len(data_df["guess"]))
# Out:
# 4080 4080 4080 264 264

# %%
data_df = {
    'mfccs': [],
    'ts': [],
    'dist': [],
    'fn': [],
    'speaker': [], 
    'guess': []
}

# %%
len(data12)
# Out:
# 2052

# %%
for i in data12:
    for j in i:
        if "MFCC" in j:
            values = j.split(" / ")
            data_df["mfccs"] += [int(values[0].split(" ")[1])] * 340
            data_df["ts"] += [float(values[1].split(" ")[1])] * 340
            data_df["dist"] += [float(values[2].split(" ")[1])] * 340
        elif len(j) == 2:
            data_df["speaker"].append(i[0])
            data_df["guess"].append(i[1])
        else:
            continue
            
data_df
# Out:
# {'mfccs': [12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
#   12,
# ...
